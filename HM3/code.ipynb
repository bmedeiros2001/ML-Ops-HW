# %% [markdown]
# ## ML Ops Homework 3
#
# **Disclaimer:** ChatGPT and Claude were used to support the completion of this assignment.

# %% [markdown]
# ## 1. Setup and Data Loading

# %%
# !pip install h2o
# !pip install "flaml[automl]"
# !pip install numpy==1.26.4
# !pip install catboost

# %%
# Data manipulation
import pandas as pd
import numpy as np
import time

# H2O AutoML
import h2o
from h2o.automl import H2OAutoML

# FLAML AutoML
from flaml import AutoML

# Train-test split
from sklearn.model_selection import train_test_split

# Evaluation
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("/Users/brunamedeiros/Documents/University of Chicago/Summer 2025 - ML Ops/HW3/athletes.csv")
print(f"Original dataset shape: {data.shape}")
data.head()
# Out:
# Original dataset shape: (423006, 27)
#    athlete_id           name               region          team  \
# 0      2554.0      Pj Ablang           South West   Double Edge
# 1      3517.0  Derek Abdella                  NaN           NaN
# 2      4691.0            NaN                  NaN           NaN
# 3      5164.0    Abo Brandon  Southern California  LAX CrossFit
# 4      5286.0    Bryce Abbey                  NaN           NaN
#
#               affiliate gender   age  height  weight   fran  ...  snatch  \
# 0  Double Edge CrossFit   Male  24.0    70.0   166.0    NaN  ...     NaN
# 1                   NaN   Male  42.0    70.0   190.0    NaN  ...     NaN
# 2                   NaN    NaN   NaN     NaN     NaN    NaN  ...     NaN
# 3          LAX CrossFit   Male  40.0    67.0     NaN  211.0  ...   200.0
# 4                   NaN   Male  32.0    65.0   149.0  206.0  ...   150.0
#
#    deadlift  backsq  pullups  \
# 0     400.0   305.0      NaN
# 1       NaN     NaN      NaN
# 2       NaN     NaN      NaN
# 3     375.0   325.0     25.0
# 4       NaN   325.0     50.0
#
#                                                  eat  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3               I eat 1-3 full cheat meals per week|
# 4  I eat quality foods but don't measure the amount|
#
#                                                train  \
# 0  I workout mostly at a CrossFit Affiliate|I hav...
# 1  I have a coach who determines my programming|I...
# 2                                                NaN
# 3  I workout mostly at a CrossFit Affiliate|I hav...
# 4  I workout mostly at a CrossFit Affiliate|I inc...
#
#                                           background  \
# 0  I played youth or high school level sports|I r...
# 1        I played youth or high school level sports|
# 2                                                NaN
# 3        I played youth or high school level sports|
# 4                           I played college sports|
#
#                                           experience  \
# 0  I began CrossFit with a coach (e.g. at an affi...
# 1  I began CrossFit with a coach (e.g. at an affi...
# 2                                                NaN
# 3  I began CrossFit by trying it alone (without a...
# 4  I began CrossFit by trying it alone (without a...
#
#                                             schedule     howlong
# 0         I do multiple workouts in a day 2x a week|   4+ years|
# 1         I do multiple workouts in a day 2x a week|   4+ years|
# 2                                                NaN         NaN
# 3                 I usually only do 1 workout a day|   4+ years|
# 4  I usually only do 1 workout a day|I strictly s...  1-2 years|
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 2. Data Cleaning

# %%
data_clean = data.copy()

# Drop NA in key columns
data_clean = data_clean.dropna(subset=[
    'region','age','weight','height','howlong','gender','eat',
    'train','background','experience','schedule','howlong',
    'deadlift','candj','snatch','backsq','experience',
    'background','schedule','howlong'
])

# Drop irrelevant columns
data_clean = data_clean.drop(columns=[
    'affiliate','team','name','fran','helen','grace','filthy50','fgonebad','run400','run5k','pullups','train'
])

# Remove outliers
data_clean = data_clean[data_clean['weight'] < 1500]
data_clean = data_clean[data_clean['gender'] != '--']
data_clean = data_clean[data_clean['age'] >= 18]
data_clean = data_clean[(data_clean['height'] < 96) & (data_clean['height'] > 48)]

data_clean = data_clean[
    ((data_clean['gender'] == 'Male') & (data_clean['deadlift'] > 0) & (data_clean['deadlift'] <= 1105)) |
    ((data_clean['gender'] == 'Female') & (data_clean['deadlift'] > 0) & (data_clean['deadlift'] <= 636))
]
data_clean = data_clean[(data_clean['candj'] > 0) & (data_clean['candj'] <= 395)]
data_clean = data_clean[(data_clean['snatch'] > 0) & (data_clean['snatch'] <= 496)]
data_clean = data_clean[(data_clean['backsq'] > 0) & (data_clean['backsq'] <= 1069)]

# Clean survey data
decline_dict = {'Decline to answer|': np.nan}
data_clean = data_clean.replace(decline_dict)
data_clean = data_clean.dropna(subset=['background','experience','schedule','howlong','eat'])

# Create target variable
data_clean['total_lift'] = (
    data_clean['deadlift'] + data_clean['candj'] +
    data_clean['snatch'] + data_clean['backsq']
)

# Do same feature engineering from HW2 so I can compare answers:
data_clean['BMI'] = (data_clean['weight'] * 703) / (data_clean['height'] ** 2)
data_clean['howlong'] = data_clean['howlong'].str.rstrip('|').str.strip()
data_clean = data_clean[~data_clean['howlong'].str.contains(r'\|', na=False)]
howlong_map = {
    "Less than 6 months": 0.5,
    "6-12 months": 1,
    "1-2 years": 1.5,
    "2-4 years": 3,
    "4+ years": 5
}
data_clean['howlong_numeric'] = data_clean['howlong'].map(howlong_map)

# I am not one-hot encoding gender. AutoML should be able to do this


data_leakage_cols = ['deadlift', 'candj', 'snatch', 'backsq', 'howlong'] # Remove data leakage columns
unnecessary_columns = ['background', 'experience', 'schedule', 'eat', 'region', 'athlete_id'] # Remove unnecessary columns
data_clean = data_clean.drop(columns=data_leakage_cols + unnecessary_columns)

print(f"Cleaned dataset shape: {data_clean.shape}")
print(f"Target variable (total_lift) statistics:")
print(data_clean['total_lift'].describe())
# Out:
# Cleaned dataset shape: (29444, 7)
# Target variable (total_lift) statistics:
# count    29444.000000
# mean      1016.511581
# std        277.449516
# min          4.000000
# 25%        804.000000
# 50%       1036.000000
# 75%       1221.000000
# max       2135.000000
# Name: total_lift, dtype: float64

# %%
data_clean.columns
# Out:
# Index(['gender', 'age', 'height', 'weight', 'total_lift', 'BMI',
#        'howlong_numeric'],
#       dtype='object')

# %% [markdown]
# ## 3. H2O AutoML
# - Uses cross-validation internally during model selection
# - Leaderboard shows validation scores (not test scores)
# - We manually evaluate on test set with .model_performance(hf_test)

# %% [markdown]
# ### 3.1 Initialize + Prepare Data

# %%
# Initialize H2O
h2o.init()

# Train/test split
train_df, test_df = train_test_split(data_clean, test_size=0.2, random_state=32)
print(f"Training set size: {train_df.shape}")
print(f"Test set size: {test_df.shape}")

# Convert to H2O frames
hf_train = h2o.H2OFrame(train_df)
hf_test = h2o.H2OFrame(test_df)

# Set target and features
target = "total_lift"
features_all = [col for col in data_clean.columns if col != "total_lift"]
print(f"Number of features: {len(features_all)}")
print(f"Features: {features_all}")
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.23" 2024-04-16 LTS; OpenJDK Runtime Environment Zulu11.72+19-CA (build 11.0.23+9-LTS); OpenJDK 64-Bit Server VM Zulu11.72+19-CA (build 11.0.23+9-LTS, mixed mode)
#   Starting server from /opt/anaconda3/lib/python3.12/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /var/folders/qf/l8sfrcpd6vq2564v1_qt31fm0000gn/T/tmpz_on9lbg
#   JVM stdout: /var/folders/qf/l8sfrcpd6vq2564v1_qt31fm0000gn/T/tmpz_on9lbg/h2o_brunamedeiros_started_from_python.out
#   JVM stderr: /var/folders/qf/l8sfrcpd6vq2564v1_qt31fm0000gn/T/tmpz_on9lbg/h2o_brunamedeiros_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# Warning: Your H2O cluster version is (3 months and 26 days) old.  There may be a newer version available.
# Please download and install the latest version from: https://h2o-release.s3.amazonaws.com/h2o/latest_stable.html
# --------------------------  ------------------------------------
# H2O_cluster_uptime:         01 secs
# H2O_cluster_timezone:       America/Chicago
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.7
# H2O_cluster_version_age:    3 months and 26 days
# H2O_cluster_name:           H2O_from_python_brunamedeiros_0cax3g
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    4.500 Gb
# H2O_cluster_total_cores:    11
# H2O_cluster_allowed_cores:  11
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.12.2 final
# --------------------------  ------------------------------------
# Training set size: (23555, 7)
# Test set size: (5889, 7)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Number of features: 6
# Features: ['gender', 'age', 'height', 'weight', 'BMI', 'howlong_numeric']

# %% [markdown]
# ### 3.2 H2O - All Features

# %%
# Run AutoML with all features
print("Running H2O AutoML with all features...")
start_time = time.time()

aml_all = H2OAutoML(max_runtime_secs=300,
                    seed=32,
                    exclude_algos=["StackedEnsemble", "DeepLearning"]) # exclude black box models
aml_all.train(x=features_all,
              y=target,
              training_frame=hf_train)

h2o_all_runtime = time.time() - start_time
# Out:
# Running H2O AutoML with all features...
# AutoML progress: |
# 12:46:08.209: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%

# %%
# Leaderboard
print('='*60)
print("H2O AutoML Leaderboard - All Features:")
print('='*60)
leaderboard_all = aml_all.leaderboard.as_data_frame()
display(leaderboard_all.head(10))


leaderboard_all = aml_all.leaderboard.as_data_frame()
all_model_ids = leaderboard_all.head(3)['model_id'].tolist()

print('='*60)
print("Top 3 Models Performance (Top 3 Features):")
print('='*60)

# Loop through top 3 models and print performance for each
for i, model_id in enumerate(all_model_ids, 1):
    model = h2o.get_model(model_id)
    perf = model.model_performance(hf_test)

    print(f"\n--- Rank {i} Model ---")
    print(f"Model Name: {model.model_id}")
    print(f"Algorithm: {model.algo}")
    print(f"RMSE: {perf.rmse():.4f}")
    print(f"R²: {perf.r2():.4f}")
    print(f"Training time: {h2o_all_runtime:.2f} seconds")
# Out:
# ============================================================
# H2O AutoML Leaderboard - All Features:
# ============================================================
# /opt/anaconda3/lib/python3.12/site-packages/h2o/frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
#                                         model_id        rmse           mse  \
# 0    GBM_grid_1_AutoML_1_20250724_124608_model_3  154.068752  23737.180442
# 1  GBM_grid_1_AutoML_1_20250724_124608_model_156  154.127977  23755.433228
# 2  GBM_grid_1_AutoML_1_20250724_124608_model_131  154.152319  23762.937436
# 3    GBM_grid_1_AutoML_1_20250724_124608_model_2  154.156008  23764.074878
# 4  GBM_grid_1_AutoML_1_20250724_124608_model_170  154.167271  23767.547555
# 5  GBM_grid_1_AutoML_1_20250724_124608_model_122  154.217446  23783.020598
# 6  GBM_grid_1_AutoML_1_20250724_124608_model_186  154.221274  23784.201349
# 7  GBM_grid_1_AutoML_1_20250724_124608_model_138  154.232574  23787.686866
# 8   GBM_grid_1_AutoML_1_20250724_124608_model_95  154.240060  23789.996143
# 9  GBM_grid_1_AutoML_1_20250724_124608_model_126  154.254215  23794.362853
#
#           mae     rmsle  mean_residual_deviance
# 0  118.742915  0.181279            23737.180442
# 1  118.851322  0.181334            23755.433228
# 2  118.742795  0.181266            23762.937436
# 3  118.874591  0.181388            23764.074878
# 4  118.878197  0.181319            23767.547555
# 5  118.836450  0.181380            23783.020598
# 6  118.810109  0.181346            23784.201349
# 7  118.783441  0.181412            23787.686866
# 8  118.835463  0.181361            23789.996143
# 9  118.874698  0.181416            23794.362853
# ============================================================
# Top 3 Models Performance (Top 3 Features):
# ============================================================
#
# --- Rank 1 Model ---
# Model Name: GBM_grid_1_AutoML_1_20250724_124608_model_3
# Algorithm: gbm
# RMSE: 152.9106
# R²: 0.6946
# Training time: 174.29 seconds
#
# --- Rank 2 Model ---
# Model Name: GBM_grid_1_AutoML_1_20250724_124608_model_156
# Algorithm: gbm
# RMSE: 153.2226
# R²: 0.6934
# Training time: 174.29 seconds
#
# --- Rank 3 Model ---
# Model Name: GBM_grid_1_AutoML_1_20250724_124608_model_131
# Algorithm: gbm
# RMSE: 153.2206
# R²: 0.6934
# Training time: 174.29 seconds
# /opt/anaconda3/lib/python3.12/site-packages/h2o/frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"

# %% [markdown]
# **Important:** H2O's leaderboard ranks models based on validation RMSE. I am demonstrating test RMSE, so final order may not be aligned with the RMSE values displayed.

# %% [markdown]
# ### 3.3 Importance and Top Features

# %%
feature_importance = aml_all.leader.varimp(use_pandas=True)
print('='*60)
print("Feature Importance")
print('='*60)
display(feature_importance)

top_5_features = feature_importance.head(5)['variable'].tolist()
print(f"Top 5 Features: {top_5_features}")

top_3_features = feature_importance.head(3)['variable'].tolist()
print(f"\nTop 3 Features for next experiment: {top_3_features}")
# Out:
# ============================================================
# Feature Importance
# ============================================================
#           variable  relative_importance  scaled_importance  percentage
# 0           gender         3.603383e+09           1.000000    0.552209
# 1           weight         1.331014e+09           0.369379    0.203974
# 2              BMI         5.417338e+08           0.150340    0.083019
# 3              age         4.212192e+08           0.116895    0.064551
# 4  howlong_numeric         3.640855e+08           0.101040    0.055795
# 5           height         2.639647e+08           0.073255    0.040452
# Top 5 Features: ['gender', 'weight', 'BMI', 'age', 'howlong_numeric']
#
# Top 3 Features for next experiment: ['gender', 'weight', 'BMI']

# %% [markdown]
# ### 3.4 H2O - Top 3 Features

# %%
print(f"Running H2O AutoML with top 3 features ({top_3_features})...")
start_time = time.time()

aml_top3 = H2OAutoML(max_runtime_secs=300,
                    seed=32,
                    exclude_algos=["StackedEnsemble", "DeepLearning"]) # exclude black box models
aml_top3.train(x=top_3_features,
              y=target,
              training_frame=hf_train)

h2o_top3_runtime = time.time() - start_time
# Out:
# Running H2O AutoML with top 3 features (['gender', 'weight', 'BMI'])...
# AutoML progress: |
# 12:49:02.620: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%

# %%
# Leaderboard
print('='*60)
print("H2O AutoML Leaderboard - Top 3 Features")
print('='*60)
leaderboard_top3 = aml_top3.leaderboard.as_data_frame()
display(leaderboard_top3.head(3))

leaderboard_top3 = aml_top3.leaderboard.as_data_frame()
top_3_model_ids = leaderboard_top3.head(3)['model_id'].tolist()

print('='*60)
print("Top 3 Models Performance (Top 3 Features):")
print('='*60)

# Loop through top 3 models and print performance for each
for i, model_id in enumerate(top_3_model_ids, 1):
    model = h2o.get_model(model_id)
    perf = model.model_performance(hf_test)

    print(f"\n--- Rank {i} Model ---")
    print(f"Model Name: {model.model_id}")
    print(f"Algorithm: {model.algo}")
    print(f"RMSE: {perf.rmse():.4f}")
    print(f"R²: {perf.r2():.4f}")
    print(f"Training time: {h2o_top3_runtime:.2f} seconds")
# Out:
# ============================================================
# H2O AutoML Leaderboard - Top 3 Features
# ============================================================
# /opt/anaconda3/lib/python3.12/site-packages/h2o/frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
#                                         model_id        rmse           mse  \
# 0  GBM_grid_1_AutoML_2_20250724_124902_model_131  175.008063  30627.822019
# 1   GBM_grid_1_AutoML_2_20250724_124902_model_99  175.012330  30629.315827
# 2  GBM_grid_1_AutoML_2_20250724_124902_model_115  175.020346  30632.121672
#
#           mae     rmsle  mean_residual_deviance
# 0  136.863551  0.200758            30627.822019
# 1  136.840827  0.200776            30629.315827
# 2  136.823486  0.200766            30632.121672
# ============================================================
# Top 3 Models Performance (Top 3 Features):
# ============================================================
#
# --- Rank 1 Model ---
# Model Name: GBM_grid_1_AutoML_2_20250724_124902_model_131
# Algorithm: gbm
# RMSE: 173.2301
# R²: 0.6081
# Training time: 160.17 seconds
#
# --- Rank 2 Model ---
# Model Name: GBM_grid_1_AutoML_2_20250724_124902_model_99
# Algorithm: gbm
# RMSE: 173.5611
# R²: 0.6066
# Training time: 160.17 seconds
#
# --- Rank 3 Model ---
# Model Name: GBM_grid_1_AutoML_2_20250724_124902_model_115
# Algorithm: gbm
# RMSE: 173.3062
# R²: 0.6078
# Training time: 160.17 seconds
# /opt/anaconda3/lib/python3.12/site-packages/h2o/frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"

# %% [markdown]
# ---
# ## 4. FLAML AutoML
# - Uses cross-validation internally during hyperparameter optimization
# - `automl_all.best_loss` = validation score from cross-validation
# - Manually evaluate on test set with .predict(X_test)

# %% [markdown]
# ### 4.1 Prepare Data
#
# **Notice:** I realized I did not remove the `athletes_id` column like I did for H20, but it ended up being the feature with smallest importance, so I decided to continue the assignment without rerunning the AutoML, in the interest of time.

# %%
target = "total_lift"
features_all_flaml = [col for col in data_clean.columns if col != "total_lift"]

X_train = train_df[features_all_flaml]
X_test = test_df[features_all_flaml]
y_train = train_df[target]
y_test = test_df[target]

print(f"FLAML Training set shape: {X_train.shape}")
print(f"FLAML Test set shape: {X_test.shape}")
# Out:
# FLAML Training set shape: (23555, 6)
# FLAML Test set shape: (5889, 6)

# %% [markdown]
# ### 4.2 FLAML AutoML - All Features

# %%
# %pip uninstall lightgbm -y
# %pip install lightgbm==3.3.5

# %%
automl_all = AutoML()
automl_all_settings = {
    "time_budget": 300,  # Reduced time for stability
    "metric": 'r2',
    "task": 'regression',
    "seed": 32,
    "estimator_list": ['rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'sgd', 'catboost'] # had to skip LightGBM because it was giving errors
}

start_time = time.time()

automl_all.fit(X_train=X_train, y_train=y_train, **automl_all_settings)
flaml_all_runtime = time.time() - start_time
y_pred_all = automl_all.predict(X_test)
# Out:
# [flaml.automl.logger: 07-24 12:52:45] {1752} INFO - task = regression
# [flaml.automl.logger: 07-24 12:52:45] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 07-24 12:52:45] {1862} INFO - Minimizing error metric: 1-r2
# [flaml.automl.logger: 07-24 12:52:45] {1979} INFO - List of ML learners in AutoML Run: ['rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'sgd', 'catboost']
# [flaml.automl.logger: 07-24 12:52:45] {2282} INFO - iteration 0, current learner rf
# [flaml.automl.logger: 07-24 12:52:45] {2417} INFO - Estimated sufficient time budget=1845s. Estimated necessary time budget=8s.
# [flaml.automl.logger: 07-24 12:52:45] {2466} INFO -  at 0.2s,	estimator rf's best error=0.4077,	best estimator rf's best error=0.4077
# [flaml.automl.logger: 07-24 12:52:45] {2282} INFO - iteration 1, current learner sgd
# [flaml.automl.logger: 07-24 12:52:49] {2466} INFO -  at 4.1s,	estimator sgd's best error=2.6202,	best estimator rf's best error=0.4077
# [flaml.automl.logger: 07-24 12:52:49] {2282} INFO - iteration 2, current learner xgboost
# [flaml.automl.logger: 07-24 12:52:49] {2466} INFO -  at 4.4s,	estimator xgboost's best error=0.6630,	best estimator rf's best error=0.4077
# [flaml.automl.logger: 07-24 12:52:49] {2282} INFO - iteration 3, current learner extra_tree
# [flaml.automl.logger: 07-24 12:53:08] {2466} INFO -  at 22.7s,	estimator xgboost's best error=0.3081,	best estimator xgboost's best error=0.3081
# [flaml.automl.logger: 07-24 12:53:08] {2282} INFO - iteration 57, current learner xgboost
# [flaml.automl.logger: 07-24 12:53:08] {2466} INFO -  at 23.1s,	estimator xgboost's best error=0.3081,	best estimator xgboost's best error=0.3081
# [flaml.automl.logger: 07-24 12:53:08] {2282} INFO - iteration 58, current learner xgboost
# [flaml.automl.logger: 07-24 12:53:08] {2466} INFO -  at 23.2s,	estimator xgboost's best error=0.3081,	best estimator xgboost's best error=0.3081
# [flaml.automl.logger: 07-24 12:53:08] {2282} INFO - iteration 59, current learner xgboost
# [flaml.automl.logger: 07-24 12:53:09] {2466} INFO -  at 23.6s,	estimator xgboost's best error=0.3081,	best estimator xgboost's best error=0.3081
# [flaml.automl.logger: 07-24 12:53:09] {2282} INFO - iteration 60, current learner xgboost
# [flaml.automl.logger: 07-24 12:53:09] {2466} INFO -  at 23.8s,	estimator xgboost's best error=0.3081,	best estimator xgboost's best error=0.3081
# [flaml.automl.logger: 07-24 12:53:09] {2282} INFO - iteration 61, current learner xgboost
# [flaml.automl.logger: 07-24 12:53:09] {2466} INFO -  at 24.1s,	estimator xgboost's best error=0.3081,	best estimator xgboost's best error=0.3081
# [flaml.automl.logger: 07-24 12:53:09] {2282} INFO - iteration 62, current learner xgboost
# [flaml.automl.logger: 07-24 12:53:09] {2466} INFO -  at 24.3s,	estimator xgboost's best error=0.3081,	best estimator xgboost's best error=0.3081
# [flaml.automl.logger: 07-24 12:53:09] {2282} INFO - iteration 63, current learner catboost
# [flaml.automl.logger: 07-24 12:53:10] {2466} INFO -  at 25.0s,	estimator catboost's best error=0.3072,	best estimator catboost's best error=0.3072
# [flaml.automl.logger: 07-24 12:53:10] {2282} INFO - iteration 64, current learner catboost
# [flaml.automl.logger: 07-24 12:53:11] {2466} INFO -  at 25.8s,	estimator catboost's best error=0.3072,	best estimator catboost's best error=0.3072
# [flaml.automl.logger: 07-24 12:53:11] {2282} INFO - iteration 65, current learner xgboost
# [flaml.automl.logger: 07-24 12:53:11] {2466} INFO -  at 26.4s,	estimator xgboost's best error=0.3081,	best estimator catboost's best error=0.3072
# [flaml.automl.logger: 07-24 12:53:11] {2282} INFO - iteration 66, current learner catboost
# [flaml.automl.logger: 07-24 12:53:12] {2466} INFO -  at 26.9s,	estimator catboost's best error=0.3072,	best estimator catboost's best error=0.3072
# [flaml.automl.logger: 07-24 12:53:12] {2282} INFO - iteration 67, current learner catboost
# [flaml.automl.logger: 07-24 12:53:13] {2466} INFO -  at 27.6s,	estimator catboost's best error=0.3072,	best estimator catboost's best error=0.3072
# [flaml.automl.logger: 07-24 12:53:13] {2282} INFO - iteration 68, current learner extra_tree
# [flaml.automl.logger: 07-24 12:53:13] {2466} INFO -  at 27.8s,	estimator extra_tree's best error=0.3272,	best estimator catboost's best error=0.3072
# [flaml.automl.logger: 07-24 12:53:13] {2282} INFO - iteration 69, current learner xgboost
	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:42] {2282} INFO - iteration 120, current learner xgboost
# [flaml.automl.logger: 07-24 12:53:45] {2466} INFO -  at 59.6s,	estimator xgboost's best error=0.3081,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:45] {2282} INFO - iteration 121, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:53:45] {2466} INFO -  at 59.7s,	estimator xgb_limitdepth's best error=0.3089,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:45] {2282} INFO - iteration 122, current learner sgd
# [flaml.automl.logger: 07-24 12:53:47] {2466} INFO -  at 61.6s,	estimator sgd's best error=0.5139,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:47] {2282} INFO - iteration 123, current learner catboost
# [flaml.automl.logger: 07-24 12:53:48] {2466} INFO -  at 62.6s,	estimator catboost's best error=0.3068,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:48] {2282} INFO - iteration 124, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:53:48] {2466} INFO -  at 62.7s,	estimator xgb_limitdepth's best error=0.3089,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:48] {2282} INFO - iteration 125, current learner xgboost
# [flaml.automl.logger: 07-24 12:53:48] {2466} INFO -  at 63.0s,	estimator xgboost's best error=0.3081,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:48] {2282} INFO - iteration 126, current learner rf
# [flaml.automl.logger: 07-24 12:53:49] {2466} INFO -  at 63.6s,	estimator rf's best error=0.3149,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:49] {2282} INFO - iteration 127, current learner rf
# [flaml.automl.logger: 07-24 12:53:49] {2466} INFO -  at 63.9s,	estimator rf's best error=0.3149,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:49] {2282} INFO - iteration 128, current learner rf
# [flaml.automl.logger: 07-24 12:53:49] {2466} INFO -  at 64.2s,	estimator rf's best error=0.3149,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:49] {2282} INFO - iteration 129, current learner xgboost
# [flaml.automl.logger: 07-24 12:53:49] {2466} INFO -  at 64.4s,	estimator xgboost's best error=0.3080,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:49] {2282} INFO - iteration 130, current learner catboost
# [flaml.automl.logger: 07-24 12:53:50] {2466} INFO -  at 65.5s,	estimator catboost's best error=0.3068,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:50] {2282} INFO - iteration 131, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:53:51] {2466} INFO -  at 65.7s,	estimator xgb_limitdepth's best error=0.3089,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:51] {2282} INFO - iteration 132, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:53:51] {2466} INFO -  at 65.8s,	estimator xgb_limitdepth's best error=0.3089,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:51] {2282} INFO - iteration 133, current learner catboost
# [flaml.automl.logger: 07-24 12:53:51] {2466} INFO -  at 66.5s,	estimator catboost's best error=0.3068,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:51] {2282} INFO - iteration 134, current learner extra_tree
# [flaml.automl.logger: 07-24 12:53:52] {2466} INFO -  at 66.7s,	estimator extra_tree's best error=0.3211,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:52] {2282} INFO - iteration 135, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:53:52] {2466} INFO -  at 67.4s,	estimator xgb_limitdepth's best error=0.3089,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:52] {2282} INFO - iteration 136, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:53:52] {2466} INFO -  at 67.5s,	estimator xgb_limitdepth's best error=0.3089,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:53:52] {2282} INFO - iteration 137, current learner catboost
# [flaml.automl.logger: 07-24 12:53:53] {2466} INFO -  at 68.4s,	estimator catboost's best error=0.3068,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12
	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:01] {2282} INFO - iteration 156, current learner extra_tree
# [flaml.automl.logger: 07-24 12:54:02] {2466} INFO -  at 76.7s,	estimator extra_tree's best error=0.3211,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:02] {2282} INFO - iteration 157, current learner catboost
# [flaml.automl.logger: 07-24 12:54:02] {2466} INFO -  at 77.5s,	estimator catboost's best error=0.3068,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:02] {2282} INFO - iteration 158, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:54:03] {2466} INFO -  at 77.9s,	estimator xgb_limitdepth's best error=0.3084,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:03] {2282} INFO - iteration 159, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:54:03] {2466} INFO -  at 78.0s,	estimator xgb_limitdepth's best error=0.3084,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:03] {2282} INFO - iteration 160, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:54:03] {2466} INFO -  at 78.1s,	estimator xgb_limitdepth's best error=0.3084,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:03] {2282} INFO - iteration 161, current learner catboost
# [flaml.automl.logger: 07-24 12:54:04] {2466} INFO -  at 79.1s,	estimator catboost's best error=0.3068,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:04] {2282} INFO - iteration 162, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:54:04] {2466} INFO -  at 79.4s,	estimator xgb_limitdepth's best error=0.3084,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:04] {2282} INFO - iteration 163, current learner sgd
# [flaml.automl.logger: 07-24 12:54:08] {2466} INFO -  at 82.8s,	estimator sgd's best error=0.5139,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:08] {2282} INFO - iteration 164, current learner catboost
# [flaml.automl.logger: 07-24 12:54:09] {2466} INFO -  at 83.7s,	estimator catboost's best error=0.3068,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:09] {2282} INFO - iteration 165, current learner catboost
# [flaml.automl.logger: 07-24 12:54:10] {2466} INFO -  at 84.7s,	estimator catboost's best error=0.3068,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:10] {2282} INFO - iteration 166, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:54:10] {2466} INFO -  at 84.8s,	estimator xgb_limitdepth's best error=0.3084,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:10] {2282} INFO - iteration 167, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:54:10] {2466} INFO -  at 85.1s,	estimator xgb_limitdepth's best error=0.3084,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:10] {2282} INFO - iteration 168, current learner sgd
# [flaml.automl.logger: 07-24 12:54:11] {2466} INFO -  at 85.9s,	estimator sgd's best error=0.4133,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:11] {2282} INFO - iteration 169, current learner catboost
# [flaml.automl.logger: 07-24 12:54:12] {2466} INFO -  at 86.9s,	estimator catboost's best error=0.3068,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:12] {2282} INFO - iteration 170, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:54:12] {2466} INFO -  at 87.2s,	estimator xgb_limitdepth's best error=0.3084,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:12] {2282} INFO - iteration 171, current learner xgboost
# [flaml.automl.logger: 07-24 12:54:12] {2466} INFO -  at 87.5s,	estimator xgboost's best error=0.3080,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:12] {2282} INFO - iteration 172, current learner extra_tree
# [flaml.automl.logger: 07-24 12:54:13] {2466} INFO -  at 87.6s,	estimator extra_tree's best error=0.3211,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12:54:13] {2282} INFO - iteration 173, current learner sgd
# [flaml.automl.logger: 07-24 12:54:17] {2466} INFO -  at 91.6s,	estimator sgd's best error=0.4133,	best estimator catboost's best error=0.3068
# [flaml.automl.logger: 07-24 12
# [flaml.automl.logger: 07-24 12:57:39] {2466} INFO -  at 294.3s,	estimator catboost's best error=0.3065,	best estimator catboost's best error=0.3065
# [flaml.automl.logger: 07-24 12:57:39] {2282} INFO - iteration 452, current learner catboost
# [flaml.automl.logger: 07-24 12:57:40] {2466} INFO -  at 295.4s,	estimator catboost's best error=0.3065,	best estimator catboost's best error=0.3065
# [flaml.automl.logger: 07-24 12:57:40] {2282} INFO - iteration 453, current learner catboost
# [flaml.automl.logger: 07-24 12:57:41] {2466} INFO -  at 296.2s,	estimator catboost's best error=0.3065,	best estimator catboost's best error=0.3065
# [flaml.automl.logger: 07-24 12:57:41] {2282} INFO - iteration 454, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:57:42] {2466} INFO -  at 297.4s,	estimator xgb_limitdepth's best error=0.3084,	best estimator catboost's best error=0.3065
# [flaml.automl.logger: 07-24 12:57:42] {2282} INFO - iteration 455, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:57:43] {2466} INFO -  at 297.6s,	estimator xgb_limitdepth's best error=0.3084,	best estimator catboost's best error=0.3065
# [flaml.automl.logger: 07-24 12:57:43] {2282} INFO - iteration 456, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:57:43] {2466} INFO -  at 297.8s,	estimator xgb_limitdepth's best error=0.3084,	best estimator catboost's best error=0.3065
# [flaml.automl.logger: 07-24 12:57:43] {2282} INFO - iteration 457, current learner catboost
# [flaml.automl.logger: 07-24 12:57:44] {2466} INFO -  at 298.6s,	estimator catboost's best error=0.3065,	best estimator catboost's best error=0.3065
# [flaml.automl.logger: 07-24 12:57:44] {2282} INFO - iteration 458, current learner catboost
# [flaml.automl.logger: 07-24 12:57:44] {2466} INFO -  at 299.5s,	estimator catboost's best error=0.3065,	best estimator catboost's best error=0.3065
# [flaml.automl.logger: 07-24 12:57:44] {2282} INFO - iteration 459, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:57:45] {2466} INFO -  at 299.7s,	estimator xgb_limitdepth's best error=0.3084,	best estimator catboost's best error=0.3065
# [flaml.automl.logger: 07-24 12:57:45] {2282} INFO - iteration 460, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:57:45] {2466} INFO -  at 300.0s,	estimator xgb_limitdepth's best error=0.3084,	best estimator catboost's best error=0.3065
# [flaml.automl.logger: 07-24 12:57:45] {2724} INFO - retrain catboost for 0.2s
# [flaml.automl.logger: 07-24 12:57:45] {2727} INFO - retrained model: <catboost.core.CatBoostRegressor object at 0x33f1fe2d0>
# [flaml.automl.logger: 07-24 12:57:45] {2009} INFO - fit succeeded
# [flaml.automl.logger: 07-24 12:57:45] {2010} INFO - Time taken to find the best model: 199.33522391319275

# %%
print('='*60)
print("FLAML Top 1 Model by Test Performance (All):")
print('='*60)

print('Best ML Learner:', automl_all.best_estimator)
print('Best hyperparameter config:', automl_all.best_config)
print('Best r2 on validation data: {0:.4g}'.format(1-automl_all.best_loss))
print('Training duration of best model: {0:.4f} s'.format(automl_all.best_config_train_time))
print('Training duration of best run: {0:.4f} s'.format(automl_all.best_config_train_time))
# Out:
# ============================================================
# FLAML Top 1 Model by Test Performance (All):
# ============================================================
# Best ML Learner: catboost
# Best hyperparameter config: {'early_stopping_rounds': 18, 'learning_rate': 0.07618189423410547, 'n_estimators': 8192}
# Best r2 on validation data: 0.6935
# Training duration of best run: 0.1982 s

# %% [markdown]
# **Important:** FLAML doesn't automatically store any model besides the 1 best performing one. To retrieve this information, one needs to look into the search history.

# %% [markdown]
# ### 4.3 FLAML Feature Importance and Top Features

# %%
top_5_features_flaml = pd.DataFrame({
   'feature': X_train.columns,
   'importance': automl_all.model.estimator.feature_importances_
}).sort_values('importance', ascending=False).head(5)['feature'].tolist()

print(f"FLAML Top 5 Features: {top_5_features_flaml}")

top_3_features_flaml = pd.DataFrame({
   'feature': X_train.columns,
   'importance': automl_all.model.estimator.feature_importances_
}).sort_values('importance', ascending=False).head(3)['feature'].tolist()

print(f"Top 3 Features for next model: {top_3_features_flaml}")
# Out:
# FLAML Top 5 Features: ['gender', 'age', 'BMI', 'howlong_numeric', 'weight']
# Top 3 Features for next model: ['gender', 'age', 'BMI']

# %% [markdown]
# ### 4.4 FLAML - Top 3 Features

# %%
print("Running FLAML AutoML with top 3 features...")
start_time = time.time()

X_train_top3 = X_train[top_3_features_flaml]
X_test_top3 = X_test[top_3_features_flaml]

automl_top3 = AutoML()
automl_top3_settings = {
    "time_budget": 300,
    "metric": 'r2',
    "task": 'regression',
    "seed": 32,
    "estimator_list": ['rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'sgd', 'catboost']
}

automl_top3.fit(X_train=X_train_top3, y_train=y_train, **automl_top3_settings)
flaml_top3_runtime = time.time() - start_time
# Out:
# Running FLAML AutoML with top 3 features...
# [flaml.automl.logger: 07-24 12:57:45] {1752} INFO - task = regression
# [flaml.automl.logger: 07-24 12:57:45] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 07-24 12:57:45] {1862} INFO - Minimizing error metric: 1-r2
# [flaml.automl.logger: 07-24 12:57:45] {1979} INFO - List of ML learners in AutoML Run: ['rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'sgd', 'catboost']
# [flaml.automl.logger: 07-24 12:57:45] {2282} INFO - iteration 0, current learner rf
# [flaml.automl.logger: 07-24 12:57:45] {2417} INFO - Estimated sufficient time budget=1748s. Estimated necessary time budget=7s.
# [flaml.automl.logger: 07-24 12:57:45] {2466} INFO -  at 0.2s,	estimator rf's best error=0.4077,	best estimator rf's best error=0.4077
# [flaml.automl.logger: 07-24 12:57:45] {2282} INFO - iteration 1, current learner sgd
# [flaml.automl.logger: 07-24 12:57:49] {2466} INFO -  at 3.6s,	estimator sgd's best error=2.6403,	best estimator rf's best error=0.4077
# [flaml.automl.logger: 07-24 12:57:49] {2282} INFO - iteration 2, current learner xgboost
# [flaml.automl.logger: 07-24 12:57:49] {2466} INFO -  at 3.8s,	estimator xgboost's best error=0.6630,	best estimator rf's best error=0.4077
# [flaml.automl.logger: 07-24 12:57:49] {2282} INFO - iteration 3, current learner rf
# [flaml.automl.logger: 07-24 12:57:52] {2466} INFO -  at 7.2s,	estimator extra_tree's best error=0.4081,	best estimator xgboost's best error=0.3648
# [flaml.automl.logger: 07-24 12:57:52] {2282} INFO - iteration 30, current learner rf
# [flaml.automl.logger: 07-24 12:57:53] {2466} INFO -  at 7.4s,	estimator rf's best error=0.3670,	best estimator xgboost's best error=0.3648
# [flaml.automl.logger: 07-24 12:57:53] {2282} INFO - iteration 31, current learner rf
# [flaml.automl.logger: 07-24 12:57:53] {2466} INFO -  at 7.5s,	estimator rf's best error=0.3670,	best estimator xgboost's best error=0.3648
# [flaml.automl.logger: 07-24 12:57:53] {2282} INFO - iteration 32, current learner xgboost
# [flaml.automl.logger: 07-24 12:57:53] {2466} INFO -  at 7.6s,	estimator xgboost's best error=0.3648,	best estimator xgboost's best error=0.3648
# [flaml.automl.logger: 07-24 12:57:53] {2282} INFO - iteration 33, current learner xgboost
# [flaml.automl.logger: 07-24 12:57:53] {2466} INFO -  at 7.7s,	estimator xgboost's best error=0.3648,	best estimator xgboost's best error=0.3648
# [flaml.automl.logger: 07-24 12:57:53] {2282} INFO - iteration 34, current learner rf
# [flaml.automl.logger: 07-24 12:57:53] {2466} INFO -  at 7.9s,	estimator rf's best error=0.3656,	best estimator xgboost's best error=0.3648
# [flaml.automl.logger: 07-24 12:57:53] {2282} INFO - iteration 35, current learner xgboost
# [flaml.automl.logger: 07-24 12:57:53] {2466} INFO -  at 7.9s,	estimator xgboost's best error=0.3648,	best estimator xgboost's best error=0.3648
# [flaml.automl.logger: 07-24 12:57:53] {2282} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 07-24 12:57:53] {2466} INFO -  at 8.1s,	estimator extra_tree's best error=0.4081,	best estimator xgboost's best error=0.3648
# [flaml.automl.logger: 07-24 12:57:53] {2282} INFO - iteration 37, current learner xgboost
# [flaml.automl.logger: 07-24 12:57:54] {2466} INFO -  at 8.4s,	estimator xgboost's best error=0.3646,	best estimator xgboost's best error=0.3646
# [flaml.automl.logger: 07-24 12:57:54] {2282} INFO - iteration 38, current learner xgboost
# [flaml.automl.logger: 07-24 12:57:54] {2466} INFO -  at 8.7s,	estimator xgboost's best error=0.3646,	best estimator xgboost's best error=0.3646
# [flaml.automl.logger: 07-24 12:57:54] {2282} INFO - iteration 39, current learner rf
# [flaml.automl.logger: 07-24 12:57:54] {2466} INFO -  at 8.9s,	estimator rf's best error=0.3656,	best estimator xgboost's best error=0.3646
# [flaml.automl.logger: 07-24 12:57:54] {2282} INFO - iteration 40, current learner xgboost
# [flaml.automl.logger: 07-24 12:57:54] {2466} INFO -  at 9.0s,	estimator xgboost's best error=0.3646,	best estimator xgboost's best error=0.3646
# [flaml.automl.logger: 07-24 12:57:54] {2282} INFO - iteration 41, current learner extra_tree
# [flaml.automl.logger: 07-24 12:57:54] {2466} INFO -  at 9.2s,	estimator extra_tree's best error=0.4081,	best estimator xgboost's best error=0.3646
# [flaml.automl.logger: 07-24 12:57:54] {2282} INFO - iteration 42, current learner rf
# [flaml.automl.logger: 07-24 12:58:59] {2282} INFO - iteration 171, current learner rf
# [flaml.automl.logger: 07-24 12:59:00] {2466} INFO -  at 74.4s,	estimator rf's best error=0.3643,	best estimator catboost's best error=0.3635
# [flaml.automl.logger: 07-24 12:59:00] {2282} INFO - iteration 172, current learner xgboost
# [flaml.automl.logger: 07-24 12:59:00] {2466} INFO -  at 74.5s,	estimator xgboost's best error=0.3638,	best estimator catboost's best error=0.3635
# [flaml.automl.logger: 07-24 12:59:00] {2282} INFO - iteration 173, current learner extra_tree
# [flaml.automl.logger: 07-24 12:59:00] {2466} INFO -  at 74.8s,	estimator extra_tree's best error=0.3691,	best estimator catboost's best error=0.3635
# [flaml.automl.logger: 07-24 12:59:00] {2282} INFO - iteration 174, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:59:00] {2466} INFO -  at 74.8s,	estimator xgb_limitdepth's best error=0.3644,	best estimator catboost's best error=0.3635
# [flaml.automl.logger: 07-24 12:59:00] {2282} INFO - iteration 175, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:59:00] {2466} INFO -  at 75.1s,	estimator xgb_limitdepth's best error=0.3644,	best estimator catboost's best error=0.3635
# [flaml.automl.logger: 07-24 12:59:00] {2282} INFO - iteration 176, current learner xgboost
# [flaml.automl.logger: 07-24 12:59:03] {2466} INFO -  at 77.4s,	estimator xgboost's best error=0.3638,	best estimator catboost's best error=0.3635
# [flaml.automl.logger: 07-24 12:59:03] {2282} INFO - iteration 177, current learner catboost
# [flaml.automl.logger: 07-24 12:59:03] {2466} INFO -  at 77.8s,	estimator catboost's best error=0.3635,	best estimator catboost's best error=0.3635
# [flaml.automl.logger: 07-24 12:59:03] {2282} INFO - iteration 178, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:59:03] {2466} INFO -  at 77.9s,	estimator xgb_limitdepth's best error=0.3644,	best estimator catboost's best error=0.3635
# [flaml.automl.logger: 07-24 12:59:03] {2282} INFO - iteration 179, current learner extra_tree
# [flaml.automl.logger: 07-24 12:59:03] {2466} INFO -  at 78.1s,	estimator extra_tree's best error=0.3691,	best estimator catboost's best error=0.3635
# [flaml.automl.logger: 07-24 12:59:03] {2282} INFO - iteration 180, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 12:59:03] {2466} INFO -  at 78.2s,	estimator xgb_limitdepth's best error=0.3644,	best estimator catboost's best error=0.3635
# [flaml.automl.logger: 07-24 12:59:03] {2282} INFO - iteration 181, current learner catboost
# [flaml.automl.logger: 07-24 12:59:04] {2466} INFO -  at 78.7s,	estimator catboost's best error=0.3635,	best estimator catboost's best error=0.3635
# [flaml.automl.logger: 07-24 12:59:04] {2282} INFO - iteration 182, current learner catboost
# [flaml.automl.logger: 07-24 12:59:04] {2466} INFO -  at 79.2s,	estimator catboost's best error=0.3635,	best estimator catboost's best error=0.3635
# [flaml.automl.logger: 07-24 12:59:04] {2282} INFO - iteration 183, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:01] {2466} INFO -  at 256.1s,	estimator rf's best error=0.3638,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:01] {2282} INFO - iteration 417, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:01] {2466} INFO -  at 256.3s,	estimator xgboost's best error=0.3634,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:01] {2282} INFO - iteration 418, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 13:02:02] {2466} INFO -  at 256.4s,	estimator xgb_limitdepth's best error=0.3644,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:02] {2282} INFO - iteration 419, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 13:02:02] {2466} INFO -  at 256.4s,	estimator xgb_limitdepth's best error=0.3644,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:02] {2282} INFO - iteration 420, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 13:02:02] {2466} INFO -  at 256.6s,	estimator xgb_limitdepth's best error=0.3644,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:02] {2282} INFO - iteration 421, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:02] {2466} INFO -  at 257.2s,	estimator xgboost's best error=0.3634,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:02] {2282} INFO - iteration 422, current learner catboost
# [flaml.automl.logger: 07-24 13:02:04] {2466} INFO -  at 258.9s,	estimator catboost's best error=0.3635,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:04] {2282} INFO - iteration 423, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:04] {2466} INFO -  at 259.2s,	estimator xgboost's best error=0.3634,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:04] {2282} INFO - iteration 424, current learner sgd
# [flaml.automl.logger: 07-24 13:02:07] {2466} INFO -  at 261.7s,	estimator sgd's best error=0.4856,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:07] {2282} INFO - iteration 425, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:08] {2466} INFO -  at 262.5s,	estimator xgboost's best error=0.3634,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:08] {2282} INFO - iteration 426, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:08] {2466} INFO -  at 262.9s,	estimator xgboost's best error=0.3634,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:08] {2282} INFO - iteration 427, current learner rf
# [flaml.automl.logger: 07-24 13:02:10] {2466} INFO -  at 264.6s,	estimator rf's best error=0.3638,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:10] {2282} INFO - iteration 428, current learner rf
# [flaml.automl.logger: 07-24 13:02:11] {2466} INFO -  at 265.7s,	estimator rf's best error=0.3638,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:11] {2282} INFO - iteration 429, current learner rf
# [flaml.automl.logger: 07-24 13:02:12] {2466} INFO -  at 266.6s,	estimator rf's best error=0.3638,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:12] {2282} INFO - iteration 430, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:12] {2466} INFO -  at 266.9s,	estimator xgboost's best error=0.3634,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:12] {2282} INFO - iteration 431, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:13] {2466} INFO -  at 267.9s,	estimator xgboost's best error=0.3634,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:13] {2282} INFO - iteration 432, current learner rf
# [flaml.automl.logger: 07-24 13:02:15] {2466} INFO -  at 269.7s,	estimator rf's best error=0.3638,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:15] {2282} INFO - iteration 433, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 13:02:15] {2466} INFO -  at 269.8s,	estimator xgb_limitdepth's best error=0.3644,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:15] {2282} INFO - iteration 434, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:15] {2466} INFO -  at 270.0s,	estimator xgboost's best error=0.3634,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:15] {2282} INFO - iteration 435, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 13:02:15] {2466} INFO -  at 270.3s,	estimator xgb_limitdepth's best error=0.3644,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:15] {2282} INFO - iteration 436, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:16] {2466} INFO -  at 270.6s,	estimator xgboost's best error=0.3634,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:16] {2282} INFO - iteration 437, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:16] {2466} INFO -  at 271.2s,	estimator xgboost's best error=0.3634,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:16] {2282} INFO - iteration 438, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:17] {2466} INFO -  at 271.4s,	estimator xgboost's best error=0.3634,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:17] {2282} INFO - iteration 439, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:17] {2466} INFO -  at 272.3s,	estimator xgboost's best error=0.3634,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:17] {2282} INFO - iteration 440, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 13:02:18] {2466} INFO -  at 272.4s,	estimator xgb_limitdepth's best error=0.3644,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:18] {2282} INFO - iteration 441, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:33] {2466} INFO -  at 287.5s,	estimator xgboost's best error=0.3634,	best estimator xgboost's best error=0.3634
# [flaml.automl.logger: 07-24 13:02:33] {2282} INFO - iteration 455, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:34] {2466} INFO -  at 288.4s,	estimator xgboost's best error=0.3633,	best estimator xgboost's best error=0.3633
# [flaml.automl.logger: 07-24 13:02:34] {2282} INFO - iteration 456, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:34] {2466} INFO -  at 288.6s,	estimator xgboost's best error=0.3633,	best estimator xgboost's best error=0.3633
# [flaml.automl.logger: 07-24 13:02:34] {2282} INFO - iteration 457, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:35] {2466} INFO -  at 290.2s,	estimator xgboost's best error=0.3633,	best estimator xgboost's best error=0.3633
# [flaml.automl.logger: 07-24 13:02:35] {2282} INFO - iteration 458, current learner catboost
# [flaml.automl.logger: 07-24 13:02:37] {2466} INFO -  at 291.6s,	estimator catboost's best error=0.3635,	best estimator xgboost's best error=0.3633
# [flaml.automl.logger: 07-24 13:02:37] {2282} INFO - iteration 459, current learner catboost
# [flaml.automl.logger: 07-24 13:02:39] {2466} INFO -  at 294.1s,	estimator catboost's best error=0.3635,	best estimator xgboost's best error=0.3633
# [flaml.automl.logger: 07-24 13:02:39] {2282} INFO - iteration 460, current learner extra_tree
# [flaml.automl.logger: 07-24 13:02:39] {2466} INFO -  at 294.3s,	estimator extra_tree's best error=0.3690,	best estimator xgboost's best error=0.3633
# [flaml.automl.logger: 07-24 13:02:39] {2282} INFO - iteration 461, current learner xgb_limitdepth
# [flaml.automl.logger: 07-24 13:02:40] {2466} INFO -  at 294.6s,	estimator xgb_limitdepth's best error=0.3644,	best estimator xgboost's best error=0.3633
# [flaml.automl.logger: 07-24 13:02:40] {2282} INFO - iteration 462, current learner catboost
# [flaml.automl.logger: 07-24 13:02:41] {2466} INFO -  at 296.3s,	estimator catboost's best error=0.3635,	best estimator xgboost's best error=0.3633
# [flaml.automl.logger: 07-24 13:02:41] {2282} INFO - iteration 463, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:42] {2466} INFO -  at 296.8s,	estimator xgboost's best error=0.3632,	best estimator xgboost's best error=0.3632
# [flaml.automl.logger: 07-24 13:02:42] {2282} INFO - iteration 464, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:43] {2466} INFO -  at 298.0s,	estimator xgboost's best error=0.3632,	best estimator xgboost's best error=0.3632
# [flaml.automl.logger: 07-24 13:02:43] {2282} INFO - iteration 465, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:43] {2466} INFO -  at 298.3s,	estimator xgboost's best error=0.3632,	best estimator xgboost's best error=0.3632
# [flaml.automl.logger: 07-24 13:02:43] {2282} INFO - iteration 466, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:45] {2466} INFO -  at 299.4s,	estimator xgboost's best error=0.3632,	best estimator xgboost's best error=0.3632
# [flaml.automl.logger: 07-24 13:02:45] {2282} INFO - iteration 467, current learner xgboost
# [flaml.automl.logger: 07-24 13:02:45] {2466} INFO -  at 299.7s,	estimator xgboost's best error=0.3632,	best estimator xgboost's best error=0.3632
# [flaml.automl.logger: 07-24 13:02:45] {2282} INFO - iteration 468, current learner extra_tree
# [flaml.automl.logger: 07-24 13:02:45] {2466} INFO -  at 299.9s,	estimator extra_tree's best error=0.3690,	best estimator xgboost's best error=0.3632
# [flaml.automl.logger: 07-24 13:02:45] {2724} INFO - retrain xgboost for 0.1s
# [flaml.automl.logger: 07-24 13:02:45] {2727} INFO - retrained model: XGBRegressor(base_score=None, booster=None, callbacks=[],
#              colsample_bylevel=0.543933125705768, colsample_bynode=None,
#              colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy='lossguide',
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.10276236833603367, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=0, max_leaves=4,
#              min_child_weight=1.3527820602007294, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=461,
#              n_jobs=-1, num_parallel_tree=None, ...)
# [flaml.automl.logger: 07-24 13:02:45] {2009} INFO - fit succeeded
# [flaml.automl.logger: 07-24 13:02:45] {2010} INFO - Time taken to find the best model: 296.77044200897217

# %%
y_pred_top3 = automl_top3.predict(X_test_top3)

print('='*60)
print("FLAML Top 1 Model by Test Performance (Top 3 Features):")
print('='*60)
print('Best ML Learner:', automl_top3.best_estimator)
print('Best hyperparameter config:', automl_top3.best_config)
print('Best r2 on validation data: {0:.4g}'.format(1-automl_top3.best_loss))
print('Training duration of best model: {0:.4f} s'.format(automl_top3.best_config_train_time))
print(f"Total training time: {flaml_top3_runtime:.2f} seconds")
# Out:
# ============================================================
# FLAML Top 1 Model by Test Performance (Top 3 Features):
# ============================================================
# Best ML Learner: xgboost
# Best hyperparameter config: {'n_estimators': 461, 'max_leaves': 4, 'min_child_weight': 1.3527820602007294, 'learning_rate': 0.10276236833603367, 'subsample': 0.9647327788976525, 'colsample_bylevel': 0.543933125705768, 'colsample_bytree': 1.0, 'reg_alpha': 0.001535032177772235, 'reg_lambda': 31.136985009903125}
# Best r2 on validation data: 0.6368
# Training duration of best run: 0.0866 s
# Total training time: 299.98 seconds

# %% [markdown]
# ## 5. Results

# %%
results_summary = []

# H2O All Features - Best Model
h2o_all_best = h2o.get_model(aml_all.leaderboard.as_data_frame().iloc[0]['model_id'])
h2o_all_perf = h2o_all_best.model_performance(hf_test)
results_summary.append({
    'Framework': 'H2O',
    'Features': 'All (6 features)',
    'Algorithm': h2o_all_best.algo,
    'Test_RMSE': h2o_all_perf.rmse(),
    'Test_R2': h2o_all_perf.r2(),
    'Total Training Time (All Models)': h2o_all_runtime,
    'Training Time of Best Model': aml_all.leader.run_time / 1000.0
})


# H2O Top 3 Features - Best Model
h2o_top3_best = h2o.get_model(aml_top3.leaderboard.as_data_frame().iloc[0]['model_id'])
h2o_top3_perf = h2o_top3_best.model_performance(hf_test)
results_summary.append({
    'Framework': 'H2O',
    'Features': 'Top 3 (gender, weight, BMI)',
    'Algorithm': h2o_top3_best.algo,
    'Test_RMSE': h2o_top3_perf.rmse(),
    'Test_R2': h2o_top3_perf.r2(),
    'Total Training Time (All Models)': h2o_top3_runtime,
    'Training Time of Best Model': aml_top3.leader.run_time / 1000.0
})

# FLAML All Features
y_pred_flaml_all = automl_all.predict(X_test)
flaml_all_rmse = mean_squared_error(y_test, y_pred_flaml_all, squared=False)
flaml_all_r2 = r2_score(y_test, y_pred_flaml_all)
results_summary.append({
    'Framework': 'FLAML',
    'Features': 'All (6 features)',
    'Algorithm': automl_all.best_estimator,
    'Test_RMSE': flaml_all_rmse,
    'Test_R2': flaml_all_r2,
    'Total Training Time (All Models)': flaml_all_runtime,
    'Training Time of Best Model': automl_all.best_config_train_time
})

# FLAML Top 3 Features
y_pred_flaml_top3 = automl_top3.predict(X_test_top3)
flaml_top3_rmse = mean_squared_error(y_test, y_pred_flaml_top3, squared=False)
flaml_top3_r2 = r2_score(y_test, y_pred_flaml_top3)
results_summary.append({
    'Framework': 'FLAML',
    'Features': 'Top 3 (gender, age, BMI)',
    'Algorithm': automl_top3.best_estimator,
    'Test_RMSE': flaml_top3_rmse,
    'Test_R2': flaml_top3_r2,
    'Total Training Time (All Models)': flaml_top3_runtime,
    'Training Time of Best Model': automl_top3.best_config_train_time
})

# Create results DataFrame
results_df = pd.DataFrame(results_summary)
results_df = results_df.round({'Test_RMSE': 4, 'Test_R2': 4, 'Training_Time': 2})

print("="*80)
print("FINAL RESULTS SUMMARY")
print("="*80)
print(results_df.to_string(index=False))
print("="*80)

# Find best performing model
best_model_idx = results_df['Test_R2'].idxmax()
best_model = results_df.iloc[best_model_idx]

print(f"\nBEST PERFORMING MODEL:")
print(f"Framework: {best_model['Framework']}")
print(f"Features: {best_model['Features']}")
print(f"Algorithm: {best_model['Algorithm']}")
print(f"Test R²: {best_model['Test_R2']:.4f}")
print(f"Test RMSE: {best_model['Test_RMSE']:.4f}")
print(f"Training Time: {best_model['Training Time of Best Model']:.2f} seconds")

# Feature importance comparison
print(f"\n" + "="*60)
print("FEATURE IMPORTANCE COMPARISON")
print("="*60)

print("\nH2O Top Features (from all features model):")
h2o_importance = aml_all.leader.varimp(use_pandas=True)
for i, row in h2o_importance.head(5).iterrows():
    print(f"{i+1}. {row['variable']}: {row['scaled_importance']:.3f}")

print(f"\nFLAML Top Features (from all features model):")
flaml_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': automl_all.model.estimator.feature_importances_
}).sort_values('importance', ascending=False)

for i, row in flaml_importance.head(5).iterrows():
    print(f"{i+1}. {row['feature']}: {row['importance']:.3f}")

print(f"\n" + "="*60)
print("FRAMEWORK COMPARISON")
print("="*60)
print(f"H2O Best R²: {results_df[results_df['Framework'] == 'H2O']['Test_R2'].max():.4f}")
print(f"FLAML Best R²: {results_df[results_df['Framework'] == 'FLAML']['Test_R2'].max():.4f}")
print(f"H2O Avg Training Time: {results_df[results_df['Framework'] == 'H2O']['Training Time of Best Model'].mean():.2f}s")
print(f"FLAML Avg Training Time: {results_df[results_df['Framework'] == 'FLAML']['Training Time of Best Model'].mean():.2f}s")
# Out:
# ================================================================================
# FINAL RESULTS SUMMARY
# ================================================================================
# Framework                    Features Algorithm  Test_RMSE  Test_R2  Total Training Time (All Models)  Training Time of Best Model
#       H2O            All (6 features)       gbm   152.9106   0.6946                        174.286040                     0.110000
#       H2O Top 3 (gender, weight, BMI)       gbm   173.2301   0.6081                        160.174460                     0.065000
#     FLAML            All (6 features)  catboost   152.7933   0.6951                        300.180503                     0.198187
#     FLAML    Top 3 (gender, age, BMI)   xgboost   166.8939   0.6362                        299.981470                     0.086600
# ================================================================================
#
# BEST PERFORMING MODEL:
# Framework: FLAML
# Features: All (6 features)
# Algorithm: catboost
# Test R²: 0.6951
# Test RMSE: 152.7933
# Training Time: 0.20 seconds
#
# ============================================================
# FEATURE IMPORTANCE COMPARISON
# ============================================================
#
# H2O Top Features (from all features model):
# 1. gender: 1.000
# 2. weight: 0.369
# 3. BMI: 0.150
# 4. age: 0.117
# 5. howlong_numeric: 0.101
#
# FLAML Top Features (from all features model):
# 1. gender: 57.613
# 2. age: 13.728
# 5. BMI: 12.045
# 6. howlong_numeric: 10.269
# 4. weight: 5.197
#
# ============================================================
# FRAMEWORK COMPARISON
# ============================================================
# H2O Best R²: 0.6946
# FLAML Best R²: 0.6951
# H2O Avg Training Time: 0.09s
# FLAML Avg Training Time: 0.14s
# /opt/anaconda3/lib/python3.12/site-packages/h2o/frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# /opt/anaconda3/lib/python3.12/site-packages/h2o/frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
results_summary = []

# HW1 RESULTS (Manually Added)
results_summary += [
    {
      'Framework': 'HW1',
      'Features':  'DVC-V1',
      'Algorithm': 'RandomForestRegressor',
      'Test_RMSE': None,
      'Test_R2':   -143413.14511,
      'Total Training Time (All Models)': None,
      'Training Time of Best Model':      None
    },
    {
      'Framework': 'HW1',
      'Features':  'DVC-V2',
      'Algorithm': 'RandomForestRegressor',
      'Test_RMSE': None,
      'Test_R2':   0.6026758,
      'Total Training Time (All Models)': None,
      'Training Time of Best Model':      None
    },
    {
      'Framework': 'HW1',
      'Features':  'DVC-V3',
      'Algorithm': 'DPKerasSGDOptimizer',
      'Test_RMSE': None,
      'Test_R2':   0.603250,
      'Total Training Time (All Models)': None,
      'Training Time of Best Model':      None
    },
    {
      'Framework': 'HW1',
      'Features':  'lakefs-v1',
      'Algorithm': 'RandomForestRegressor',
      'Test_RMSE': None,
      'Test_R2':   -143413.1451140,
      'Total Training Time (All Models)': None,
      'Training Time of Best Model':      None
    },
    {
      'Framework': 'HW1',
      'Features':  'lakefs-v2',
      'Algorithm': 'RandomForestRegressor',
      'Test_RMSE': None,
      'Test_R2':   0.60267582,
      'Total Training Time (All Models)': None,
      'Training Time of Best Model':      None
    },
    {
      'Framework': 'HW1',
      'Features':  'lakefs-v3',
      'Algorithm': 'DPKerasSGDOptimizer',
      'Test_RMSE': None,
      'Test_R2':   0.610,
      'Total Training Time (All Models)': None,
      'Training Time of Best Model':      None
    }
]

# HW2 RESULTS (Manually Added)
results_summary += [
    {
      'Framework': 'HW2',
      'Features':  'Version v1',
      'Algorithm': 'RandomForestRegressor',
      'Test_RMSE': 173.574468,
      'Test_R2':   0.603250,
      'Total Training Time (All Models)': None,
      'Training Time of Best Model':      None
    },
    {
      'Framework': 'HW2',
      'Features':  'Version v2',
      'Algorithm': 'RandomForestRegressor',
      'Test_RMSE': 167.046094,
      'Test_R2':   0.630611,
      'Total Training Time (All Models)': None,
      'Training Time of Best Model':      None
    }
]

# H2O All Features - Best Model
h2o_all_best = h2o.get_model(aml_all.leaderboard.as_data_frame().iloc[0]['model_id'])
h2o_all_perf = h2o_all_best.model_performance(hf_test)
results_summary.append({
    'Framework': 'H2O',
    'Features': 'All (6 features)',
    'Algorithm': h2o_all_best.algo,
    'Test_RMSE': h2o_all_perf.rmse(),
    'Test_R2': h2o_all_perf.r2(),
    'Total Training Time (All Models)': h2o_all_runtime,
    'Training Time of Best Model': aml_all.leader.run_time / 1000.0
})


# H2O Top 3 Features - Best Model
h2o_top3_best = h2o.get_model(aml_top3.leaderboard.as_data_frame().iloc[0]['model_id'])
h2o_top3_perf = h2o_top3_best.model_performance(hf_test)
results_summary.append({
    'Framework': 'H2O',
    'Features': 'Top 3 (gender, weight, BMI)',
    'Algorithm': h2o_top3_best.algo,
    'Test_RMSE': h2o_top3_perf.rmse(),
    'Test_R2': h2o_top3_perf.r2(),
    'Total Training Time (All Models)': h2o_top3_runtime,
    'Training Time of Best Model': aml_top3.leader.run_time / 1000.0
})

# FLAML All Features
y_pred_flaml_all = automl_all.predict(X_test)
flaml_all_rmse = mean_squared_error(y_test, y_pred_flaml_all, squared=False)
flaml_all_r2 = r2_score(y_test, y_pred_flaml_all)
results_summary.append({
    'Framework': 'FLAML',
    'Features': 'All (6 features)',
    'Algorithm': automl_all.best_estimator,
    'Test_RMSE': flaml_all_rmse,
    'Test_R2': flaml_all_r2,
    'Total Training Time (All Models)': flaml_all_runtime,
    'Training Time of Best Model': automl_all.best_config_train_time
})

# FLAML Top 3 Features
y_pred_flaml_top3 = automl_top3.predict(X_test_top3)
flaml_top3_rmse = mean_squared_error(y_test, y_pred_flaml_top3, squared=False)
flaml_top3_r2 = r2_score(y_test, y_pred_flaml_top3)
results_summary.append({
    'Framework': 'FLAML',
    'Features': 'Top 3 (gender, age, BMI)',
    'Algorithm': automl_top3.best_estimator,
    'Test_RMSE': flaml_top3_rmse,
    'Test_R2': flaml_top3_r2,
    'Total Training Time (All Models)': flaml_top3_runtime,
    'Training Time of Best Model': automl_top3.best_config_train_time
})



results_df = pd.DataFrame(results_summary)

# Round numeric columns
results_df['Test_RMSE'] = results_df['Test_RMSE'].round(4)
results_df['Test_R2']   = results_df['Test_R2'].round(4)

# Times may be None → NaN after to_numeric
for col in ['Total Training Time (All Models)', 'Training Time of Best Model']:
    results_df[col] = pd.to_numeric(results_df[col], errors='coerce').round(2)

print("="*80)
print("FINAL RESULTS SUMMARY (HW2 & HW3)")
print("="*80)
print(results_df.to_string(index=False))
print("="*80)
# Out:
# ================================================================================
# FINAL RESULTS SUMMARY (HW2 & HW3)
# ================================================================================
# Framework                    Features             Algorithm  Test_RMSE      Test_R2  Total Training Time (All Models)  Training Time of Best Model
#       HW1                      DVC-V1 RandomForestRegressor        NaN -143413.1451                               NaN                          NaN
#       HW1                      DVC-V2 RandomForestRegressor        NaN       0.6027                               NaN                          NaN
#       HW1                      DVC-V3   DPKerasSGDOptimizer        NaN       0.6032                               NaN                          NaN
#       HW1                   lakefs-v1 RandomForestRegressor        NaN -143413.1451                               NaN                          NaN
#       HW1                   lakefs-v2 RandomForestRegressor        NaN       0.6027                               NaN                          NaN
#       HW1                   lakefs-v3   DPKerasSGDOptimizer        NaN       0.6100                               NaN                          NaN
#       HW2                  Version v1 RandomForestRegressor   173.5745       0.6032                               NaN                          NaN
#       HW2                  Version v2 RandomForestRegressor   167.0461       0.6306                               NaN                          NaN
#       H2O            All (6 features)                   gbm   152.9106       0.6946                            174.29                         0.11
#       H2O Top 3 (gender, weight, BMI)                   gbm   173.2301       0.6081                            160.17                         0.06
#     FLAML            All (6 features)              catboost   152.7933       0.6951                            300.18                         0.20
#     FLAML    Top 3 (gender, age, BMI)               xgboost   166.8939       0.6362                            299.98                         0.09
# ================================================================================
# /opt/anaconda3/lib/python3.12/site-packages/h2o/frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# /opt/anaconda3/lib/python3.12/site-packages/h2o/frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# **Notes:** Here are some important notes regarding NaNs in the comparison table
# - MAE was used instead of RMSE. When I reran the first assignment's notebook, the RMSE scores were plain unreasonable. In the interest of time, I decided to just compare the r2.
# - For assignments 1 and 2, I was not able to get the time it took to run the models.
# - DVC-V1 and lakefs-V1 had substandard R2 scores because the data was not cleaned. That was a requirement of the assignment.
# - **Missing models:** Although having attempted to solve the issue, the H2O ML constantly failed to use XGBoost model, and FLAML failed to use LightGBM. I had to discart both model in order to complete the assignment.

# %% [markdown]
# ## 6. Conclusions
#
# **Results:** The AutoML models both performed better than the models used in assignment 1 and 2. It is important to note that I performed the same data manipulation as assignment 2. Both H20 and FLAML models achieved a higher R2. There was an improvement from HW1 to HW2, and even more from HW2 to HW3.
#
# **Is your platform low-code?:** In my opinion, both H2O and FLAML can be considered low-code, but simply because we don't have to test many models—which is exactly what AutoML does. However, each AutoML platform handled data cleaning differently, and FLAML, specifically, struggled to work with the categorical columns. Because of that, I had to manually clean data so we could solely test their performance in picking the best model. Additionally, one thing I disliked is that, visualizing performance for models in FLAML. You can only analyze performance of the top best model. That is not the case for H2O.
#
# Overall, I preferred working with H2O because it required less data cleaning and analysis of model performance accross X top performing models, not just one.
